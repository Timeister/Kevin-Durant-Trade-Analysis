# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
NBA201415RS = pd.read_excel("2014-2015 Player Regular Season Stats.xlsx", header = 0, index_col =0)

# %%
NBA201415RS.head()
# Out:
#              Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  ...   \
# Player                                                               ...
# A.J. Price    Cle  PG   28  11   7.9  16.4  21.0  0.076    6  0.667  ...
# A.J. Price    Ind  PG   28  10  19.3  40.2  25.4  0.094   18  0.667  ...
# A.J. Price    Pho  PG   28   5   8.8  18.2  15.3  0.067    0  0.000  ...
# Aaron Brooks  Chi  PG   30  82  23.0  47.9  25.4  0.149  174  0.833  ...
# Aaron Gordon  Orl  PF   19  47  17.0  35.3  15.8  0.139   61  0.721  ...
#
#                 TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# Player
# A.J. Price    0.300   2.0  1.4   9.9  1.2  22.1  0.27  0.00  7.6  2015
# A.J. Price    0.542  10.5  1.4   4.0  2.7  25.3  0.40  0.00  7.1  2015
# A.J. Price    0.214   1.2  0.6   3.8  1.2  18.8  0.00  0.00  4.3  2015
# Aaron Brooks  0.534  11.6  2.0   4.8  3.2  24.2  0.66  0.18  7.3  2015
# Aaron Gordon  0.517   5.2  3.6  12.0  0.7   6.3  0.45  0.47  5.5  2015
#
# ...

# %%
len(NBA201415RS)
# Out:
# 546

# %%
NBA1 = NBA201415RS.ix[['Kevin Durant','Andrew Bogut','Leandro Barbosa','Marreese Speights','Harrison Barnes','Stephen Curry','Klay Thompson'],:]
NBA1.head()
# Out:
#                   Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  \
# Player
# Kevin Durant       Okc  SF   26  27  33.8  70.4  29.5  0.120  171  0.854
# Andrew Bogut       Gol   C   30  67  23.6  49.2  13.4  0.221   42  0.524
# Leandro Barbosa    Gol  SG   32  66  14.9  31.0  20.8  0.095   74  0.784
# Marreese Speights  Gol  PF   27  76  15.9  33.1  29.5  0.102  178  0.843
# Harrison Barnes    Gol  SF   22  82  28.3  58.9  15.1  0.090  150  0.720
#
#                    ...     TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG    VI  \
# Player             ...
# Kevin Durant       ...   0.633  25.4  6.6  10.5  4.1  22.2  0.89  0.93  10.4
# Andrew Bogut       ...   0.565   6.3  8.1  18.5  2.7  15.4  0.58  1.69   8.8
# Leandro Barbosa    ...   0.558   7.1  1.4   5.0  1.5  14.9  0.62  0.12   6.6
# Marreese Speights  ...   0.546  10.4  4.3  14.5  1.0  10.1  0.26  0.45   8.9
# Harrison Barnes    ...   0.573  10.1  5.5  10.5  1.4   6.9  0.74  0.23   6.0
#
#                    Year
# ...

# %%
NBA201516RS = pd.read_excel("2015-2016 Regular Season Stats.xlsx", header = 0, index_col =0)

# %%
NBA201516RS.head()
# Out:
#               Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  ...   \
# Player                                                                ...
# Aaron Brooks   Chi  PG   31  69  16.1  33.4  23.0  0.141   64  0.766  ...
# Aaron Gordon   Orl  PF   20  78  23.9  49.8  17.3  0.090  193  0.668  ...
# Adreian Payne  Min  PF   24  52   9.3  19.5  17.9  0.186   26  0.654  ...
# Al Horford     Atl   C   29  82  32.1  66.9  20.6  0.088  129  0.798  ...
# Al Jefferson   Cha   C   31  47  23.3  48.6  24.2  0.058  111  0.649  ...
#
#                  TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# Player
# Aaron Brooks   0.493   7.1  1.5   4.8  2.6  26.0  0.43  0.14  7.5  2016
# Aaron Gordon   0.541   9.2  6.5  15.1  1.6  10.3  0.76  0.71  7.7  2016
# Adreian Payne  0.419   2.5  2.2  13.4  0.6   8.9  0.31  0.21  6.4  2016
# Al Horford     0.565  15.2  7.3  12.4  3.2  16.8  0.83  1.49  8.8  2016
# Al Jefferson   0.507  12.0  6.4  15.0  1.5  11.8  0.64  0.87  8.4  2016
#
# ...

# %%
NBA2 = NBA201516RS.ix[['Kevin Durant','Andrew Bogut','Leandro Barbosa','Marreese Speights','Harrison Barnes','Stephen Curry','Klay Thompson','Brandon Rush','Draymond Green','Andre Iguodala','Festus Ezeli','Ian Clark','James Michael McAdoo','Jason Thompson','Shaun Livingston'],:]
NBA2.head()
# Out:
#                   Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  \
# Player
# Kevin Durant       Okc  SF   27  72  35.8  74.6  30.6  0.135  498  0.898
# Andrew Bogut       Gol   C   31  70  20.7  43.2  11.4  0.216   50  0.480
# Leandro Barbosa    Gol  SG   33  68  15.9  33.1  18.1  0.118   62  0.839
# Marreese Speights  Gol  PF   28  72  11.6  24.1  29.7  0.115  114  0.825
# Harrison Barnes    Gol  SF   23  66  30.9  64.4  15.9  0.076  134  0.761
#
#                    ...     TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG    VI  \
# Player             ...
# Kevin Durant       ...   0.634  28.2  8.2  12.4  5.0  24.2  0.96  1.18  11.7
# Andrew Bogut       ...   0.623   5.4  7.0  18.3  2.3  14.7  0.46  1.63   8.6
# Leandro Barbosa    ...   0.545   6.4  1.7   5.8  1.2  10.6  0.65  0.15   5.9
# Marreese Speights  ...   0.506   7.1  3.3  15.5  0.8  11.4  0.26  0.47   9.2
# Harrison Barnes    ...   0.559  11.7  4.9   8.6  1.8   7.8  0.62  0.15   6.1
#
#                    Year
# ...

# %%
NBA201617RS = pd.read_excel("2016-2017 Regular Season Stats.xlsx", header = 0, index_col =0)

# %%
NBA201617RS.head()
# Out:
#               Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  ...   \
# Player                                                                ...
# Aaron Brooks   Ind  PG   32  65  13.7  28.6  19.2  0.170   40  0.800  ...
# Aaron Gordon   Orl  SF   21  80  28.7  59.8  20.1  0.085  217  0.719  ...
# Adreian Payne  Min  PF   25  18   7.5  15.7  23.0  0.114   19  0.737  ...
# AJ Hammons     Dal   C   24  22   7.4  15.5  17.6  0.164   20  0.450  ...
# Al Horford     Bos   C   30  68  32.3  67.2  19.7  0.118  135  0.800  ...
#
#                  TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# Player
# Aaron Brooks   0.507   5.0  1.1   4.3  1.9  20.7  0.38  0.14  6.4  2017
# Aaron Gordon   0.530  12.7  5.1   9.6  1.9  10.5  0.81  0.50  6.9  2017
# Adreian Payne  0.505   3.5  1.8  14.2  0.4   8.0  0.44  0.39  7.3  2017
# AJ Hammons     0.472   2.2  1.7  13.2  0.2   3.8  0.05  0.59  4.9  2017
# Al Horford     0.553  14.0  6.8  11.8  5.0  24.4  0.76  1.26  9.7  2017
#
# ...

# %%
NBA3 = NBA201617RS.ix[['Kevin Durant','Andrew Bogut','Leandro Barbosa','Marreese Speights','Harrison Barnes','Stephen Curry','Klay Thompson','Brandon Rush','Draymond Green','Andre Iguodala','Ian Clark','James Michael McAdoo','Shaun Livingston'],:]
NBA3.head()
# Out:
#                   Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  \
# Player
# Kevin Durant       Gol  SF   28  62  33.4  69.6  27.8  0.104  384  0.875
# Andrew Bogut       Dal   C   32  26  22.4  46.7  10.4  0.334   11  0.273
# Leandro Barbosa    Pho  SG   34  67  14.4  30.0  20.0  0.104   45  0.889
# Marreese Speights  Lac   C   29  82  15.7  32.7  23.6  0.102  137  0.876
# Harrison Barnes    Dal  PF   24  79  35.5  73.9  25.3  0.068  281  0.861
#
#                    ...     TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG    VI  \
# Player             ...
# Kevin Durant       ...   0.651  25.1  8.3  13.6  4.8  23.1  1.06  1.60  12.0
# Andrew Bogut       ...   0.460   3.0  8.4  21.7  1.9  12.3  0.50  0.96   6.5
# Leandro Barbosa    ...   0.509   6.3  1.6   5.9  1.2  13.0  0.46  0.12   6.4
# Marreese Speights  ...   0.584   8.7  4.5  16.2  0.8   8.1  0.28  0.50   8.0
# Harrison Barnes    ...   0.541  19.2  5.0   8.2  1.5   7.8  0.82  0.19   5.9
#
#                    Year
# ...

# %%
NBA_final = pd.concat([NBA1,NBA2,NBA3])
NBA_final
# Out:
#                      Team Pos  Age  GP   MPG  MIN%  USG%    Tor  FTA    FT%  \
# Player
# Kevin Durant          Okc  SF   26  27  33.8  70.4  29.5  0.120  171  0.854
# Andrew Bogut          Gol   C   30  67  23.6  49.2  13.4  0.221   42  0.524
# Leandro Barbosa       Gol  SG   32  66  14.9  31.0  20.8  0.095   74  0.784
# Marreese Speights     Gol  PF   27  76  15.9  33.1  29.5  0.102  178  0.843
# Harrison Barnes       Gol  SF   22  82  28.3  58.9  15.1  0.090  150  0.720
# Stephen Curry         Gol  PG   26  80  32.7  68.1  29.4  0.143  337  0.914
# Klay Thompson         Gol  SG   24  77  31.9  66.4  28.1  0.095  256  0.879
# Kevin Durant          Okc  SF   27  72  35.8  74.6  30.6  0.135  498  0.898
# Andrew Bogut          Gol   C   31  70  20.7  43.2  11.4  0.216   50  0.480
# Leandro Barbosa       Gol  SG   33  68  15.9  33.1  18.1  0.118   62  0.839
# Marreese Speights     Gol  PF   28  72  11.6  24.1  29.7  0.115  114  0.825
# ...

# %%
NBA_final.to_csv('NBA.csv', sep=',')
